# %% [markdown]
# # 🏠 Housing Price Prediction Using Machine Learning
#
# ## Project Overview
#
# This project focuses on developing a machine learning model to predict the **median house value** of residential districts using geographic, demographic, housing, and socioeconomic information.
#
# The dataset contains information about housing districts, including their geographic location, median housing age, number of rooms, number of bedrooms, population, number of households, median income, and proximity to the ocean.
#
# The main objective of this project is to demonstrate a complete machine learning workflow, beginning with data loading and understanding, followed by data cleaning, exploratory data analysis, visualization, preprocessing, model development, prediction, evaluation, comparison, and interpretation.
#
# The project will use Python and several data science and machine learning libraries, including Pandas, NumPy, Matplotlib, Seaborn, and Scikit-learn.
#
# ---
#
# ## 🎯 Project Objective
#
# The primary objective of this project is to develop a machine learning model capable of predicting the **median house value** of a housing district based on the characteristics available in the dataset.
#
# The main question being investigated is:
#
# > **Can we predict the median house value of a housing district using its geographic, demographic, housing, and socioeconomic characteristics?**
#
# This is a **supervised machine learning problem** because the dataset contains a known target variable, `median_house_value`, which the model will learn to predict.
#
# Since `median_house_value` is a continuous numerical variable, this problem is classified as a **regression problem**.
#
# ---
#
# ## 📊 Dataset Description
#
# The dataset contains **20,640 observations and 10 variables**.
#
# Each row represents a housing district, while each column represents a characteristic or measurement associated with that district.
#
# The variables in the dataset are:
#
# | Variable | Description |
# |---|---|
# | `longitude` | Geographic longitude of the housing district |
# | `latitude` | Geographic latitude of the housing district |
# | `housing_median_age` | Median age of houses in the district |
# | `total_rooms` | Total number of rooms in the district |
# | `total_bedrooms` | Total number of bedrooms in the district |
# | `population` | Total population of the district |
# | `households` | Total number of households in the district |
# | `median_income` | Median income of households in the district |
# | `median_house_value` | Median house value and the target variable |
# | `ocean_proximity` | Categorical variable describing the district's proximity to the ocean |
#
# The dataset contains both **numerical** and **categorical** variables. This distinction will be important when preparing the data for machine learning.
#
# ---
#
# ## 🎯 Target Variable
#
# The target variable for this project is:
#
# ```text
# median_house_value
# ````
#
# This is the value that the machine learning models will attempt to predict.
#
# The remaining variables will be used as features.
#
# ### Features (X)
#
# The features used by the model include:
#
# ```text
# longitude
# latitude
# housing_median_age
# total_rooms
# total_bedrooms
# population
# households
# median_income
# ocean_proximity
# ```
#
# ### Target (y)
#
# The target variable is:
#
# ```text
# median_house_value
# ```
#
# The machine learning problem can therefore be represented as:
#
# ```text
# Geographic Information
#         +
# Housing Characteristics
#         +
# Demographic Information
#         +
# Socioeconomic Information
#         +
# Ocean Proximity
#         ↓
# Machine Learning Model
#         ↓
# Predicted Median House Value
# ```
#
# ---
#
# ## 🔎 Initial Data Quality Assessment
#
# Before building a machine learning model, the dataset must first be inspected to understand its structure, data types, completeness, and statistical characteristics.
#
# The dataset contains 20,640 observations and 10 columns.
#
# Most of the variables are numerical, while `ocean_proximity` is a categorical variable.
#
# Initial inspection also shows that the `total_bedrooms` column contains **207 missing values**.
#
# These missing values will need to be handled before the machine learning models are trained.
#
# Rather than deleting the observations containing missing values, the project will use an appropriate preprocessing method to replace missing numerical values with the median value of the corresponding feature.
#
# This approach allows the available observations to be retained while preparing the data for machine learning.
#
# ---
#
# ## 🔤 Categorical Data
#
# The `ocean_proximity` variable contains categorical information describing the proximity of a housing district to the ocean.
#
# Because machine learning algorithms generally require numerical input, this categorical variable cannot be supplied directly to the models in its original text form.
#
# Therefore, `ocean_proximity` will be transformed into numerical features using **One-Hot Encoding**.
#
# One-Hot Encoding creates separate numerical indicators for the different categories without incorrectly implying that one category is numerically greater or smaller than another.
#
# ---
#
# ## 🧹 Data Preprocessing
#
# Data preprocessing is an essential stage of the machine learning workflow.
#
# The following preprocessing steps will be performed:
#
# 1. Inspect the dataset structure.
# 2. Identify missing values.
# 3. Handle missing values in `total_bedrooms`.
# 4. Identify numerical variables.
# 5. Identify categorical variables.
# 6. Apply appropriate preprocessing to numerical variables.
# 7. Encode the categorical `ocean_proximity` variable.
# 8. Prepare the processed data for machine learning.
#
# A Scikit-learn **Pipeline** and **ColumnTransformer** will be used to organize the preprocessing steps.
#
# Using a pipeline helps ensure that the same preprocessing procedures are applied consistently to the training and testing datasets.
#
# ---
#
# ## 📈 Exploratory Data Analysis
#
# Before training the machine learning models, exploratory data analysis (EDA) will be performed to understand the characteristics and patterns within the dataset.
#
# The exploratory analysis will include:
#
# * Examining the structure of the dataset
# * Examining data types
# * Identifying missing values
# * Generating descriptive statistics
# * Examining distributions of numerical variables
# * Investigating relationships between variables
# * Examining correlations between numerical variables
# * Investigating the relationship between median income and house value
# * Examining house values in relation to ocean proximity
#
# Visualizations will be created using **Matplotlib** and **Seaborn**.
#
# Planned visualizations may include:
#
# * Distribution of median house values
# * Distribution of median income
# * Correlation heatmap
# * Median house value by ocean proximity
# * Median income versus median house value
# * Housing age distribution
# * Relationships between housing characteristics and house values
#
# The purpose of exploratory data analysis is to understand the data before developing the predictive models.
#
# ---
#
# ## 🤖 Machine Learning Approach
#
# This project uses **supervised machine learning**.
#
# Supervised machine learning involves training a model using observations where the correct outcome is already known.
#
# In this project, the model will be provided with housing characteristics and the corresponding `median_house_value`.
#
# The model will learn relationships between the features and the target variable and then use those learned relationships to predict house values for previously unseen observations.
#
# The overall machine learning workflow will be:
#
# ```text
# Raw Dataset
#      ↓
# Data Understanding
#      ↓
# Data Cleaning
#      ↓
# Exploratory Data Analysis
#      ↓
# Data Visualization
#      ↓
# Feature Selection
#      ↓
# Train/Test Split
#      ↓
# Data Preprocessing
#      ↓
# Model Training
#      ↓
# Prediction
#      ↓
# Model Evaluation
#      ↓
# Model Comparison
#      ↓
# Final Prediction
# ```
#
# ---
#
# ## 🧪 Train/Test Split
#
# The dataset will be divided into training and testing datasets.
#
# ### Training Data
#
# Approximately **80% of the observations** will be used as training data.
#
# The machine learning models will learn patterns from this portion of the dataset.
#
# ### Testing Data
#
# Approximately **20% of the observations** will be reserved as testing data.
#
# The testing data will not be used to train the models. Instead, it will be used to evaluate how well the trained models perform on previously unseen observations.
#
# A `random_state` will be used so that the train/test split can be reproduced when the notebook is run again.
#
# ---
#
# ## 🧠 Machine Learning Models
#
# Three regression algorithms will be developed and compared.
#
# ### 1. Linear Regression
#
# Linear Regression will be used as a baseline model.
#
# It attempts to establish a linear relationship between the input features and the target variable.
#
# The purpose of using Linear Regression as the initial model is to establish a simple benchmark against which more complex models can be compared.
#
# ---
#
# ### 2. Decision Tree Regressor
#
# A Decision Tree Regressor will also be developed.
#
# A decision tree makes predictions by repeatedly dividing observations based on feature values.
#
# This type of model can capture nonlinear relationships between housing characteristics and house values.
#
# The Decision Tree model will be compared against Linear Regression to determine whether the additional flexibility improves predictive performance.
#
# ---
#
# ### 3. Random Forest Regressor
#
# A Random Forest Regressor will be used as a more advanced machine learning model.
#
# Random Forest combines predictions from multiple decision trees to produce a final prediction.
#
# The purpose of including Random Forest is to determine whether an ensemble-based approach can produce more accurate predictions than the individual decision tree and linear regression models.
#
# ---
#
# ## 📏 Model Evaluation
#
# After training the models, their performance will be evaluated using several regression metrics.
#
# The main evaluation metrics will be:
#
# ### Mean Absolute Error (MAE)
#
# Mean Absolute Error measures the average absolute difference between the actual house values and the values predicted by the model.
#
# A lower MAE indicates better performance.
#
# The MAE can be interpreted as the approximate average amount by which the model's predictions differ from the actual house values.
#
# ---
#
# ### Root Mean Squared Error (RMSE)
#
# Root Mean Squared Error measures the square root of the average squared prediction errors.
#
# RMSE gives greater importance to larger prediction errors than MAE.
#
# A lower RMSE indicates better model performance.
#
# ---
#
# ### R² Score
#
# The R² score measures the proportion of variation in the target variable that can be explained by the model.
#
# A higher R² score generally indicates better predictive performance.
#
# The three metrics will be considered together when comparing the models rather than relying on a single metric.
#
# ---
#
# ## 📊 Model Comparison
#
# After training and evaluating the three models, their performance will be summarized in a comparison table.
#
# The table will contain:
#
# | Model                   | MAE | RMSE | R² |
# | ----------------------- | --: | ---: | -: |
# | Linear Regression       |   — |    — |  — |
# | Decision Tree Regressor |   — |    — |  — |
# | Random Forest Regressor |   — |    — |  — |
#
# The actual values will be calculated after each model has been trained and evaluated.
#
# The model with the strongest overall performance will be selected as the preferred model for this project based on the evaluation results.
#
# ---
#
# ## 📉 Actual vs Predicted Values
#
# The project will include a visualization comparing:
#
# ```text
# Actual House Values
#         vs.
# Predicted House Values
# ```
#
# A scatter plot will be used to visualize how closely the model's predictions correspond to the actual values.
#
# If the model performs well, the predicted values should generally follow a pattern close to the actual values.
#
# This visualization will provide an intuitive way of examining the model's predictive performance.
#
# ---
#
# ## 📊 Prediction Error Analysis
#
# Prediction errors will also be examined.
#
# An error can be represented as:
#
# ```text
# Prediction Error = Actual Value - Predicted Value
# ```
#
# The distribution of prediction errors will be visualized to determine how the errors are distributed.
#
# This analysis can help identify whether the model tends to make large errors for certain observations or whether there are noticeable patterns in the prediction errors.
#
# ---
#
# ## 🔮 Making Predictions on New Data
#
# After the models have been trained and evaluated, the selected model will be used to make predictions for a new housing district.
#
# The new observation will contain the same features used during model training, including:
#
# ```text
# longitude
# latitude
# housing_median_age
# total_rooms
# total_bedrooms
# population
# households
# median_income
# ocean_proximity
# ```
#
# The trained machine learning pipeline will process the new input and produce an estimated `median_house_value`.
#
# This demonstrates how a trained machine learning model can be applied to previously unseen data.
#
# ---
#
# ## 🛠️ Technologies and Libraries
#
# The project will be implemented using Python.
#
# The major libraries used include:
#
# ### Pandas
#
# Pandas will be used for:
#
# * Loading the CSV dataset
# * Creating and manipulating DataFrames
# * Data cleaning
# * Data inspection
# * Data transformation
# * Exploratory data analysis
#
# ### NumPy
#
# NumPy will be used for numerical operations and calculations.
#
# ### Matplotlib
#
# Matplotlib will be used to create charts and visualizations for exploratory analysis and model evaluation.
#
# ### Seaborn
#
# Seaborn will be used to create statistical visualizations, including distribution plots, scatter plots, boxplots, and correlation heatmaps.
#
# ### Scikit-learn
#
# Scikit-learn will be used for:
#
# * Train/test splitting
# * Data preprocessing
# * Missing-value imputation
# * One-hot encoding
# * Pipeline creation
# * Machine learning model development
# * Prediction
# * Model evaluation
#
# ---
#
# ## 📚 Project Learning Objectives
#
# By completing this project, I aim to demonstrate my ability to:
#
# 1. Load a real-world dataset into Python.
# 2. Understand the structure and characteristics of a dataset.
# 3. Inspect data types and identify missing values.
# 4. Perform exploratory data analysis using Pandas.
# 5. Generate descriptive statistics.
# 6. Create meaningful data visualizations.
# 7. Identify numerical and categorical variables.
# 8. Separate features from the target variable.
# 9. Split a dataset into training and testing sets.
# 10. Handle missing values appropriately.
# 11. Encode categorical variables.
# 12. Build machine learning preprocessing pipelines.
# 13. Train supervised machine learning models.
# 14. Make predictions using trained models.
# 15. Evaluate regression models using MAE, RMSE, and R².
# 16. Compare multiple machine learning algorithms.
# 17. Select an appropriate model based on evaluation results.
# 18. Visualize actual and predicted values.
# 19. Analyze prediction errors.
# 20. Use the final model to make predictions on new observations.
# 21. Interpret the results of a machine learning model.
# 22. Communicate the findings and limitations of the analysis.
#
# ---
#
# ## ⚠️ Project Limitations
#
# Although this project demonstrates a complete machine learning workflow, the results should be interpreted within the limitations of the dataset.
#
# A machine learning model learns patterns from the data provided to it. Therefore, the quality, completeness, representativeness, and characteristics of the dataset can influence model performance.
#
# There may also be other factors that influence house prices that are not included in the dataset.
#
# These may include:
#
# * Individual property characteristics
# * Property condition
# * Local economic conditions
# * Interest rates
# * Housing supply and demand
# * Infrastructure
# * School quality
# * Neighborhood characteristics
# * Changes in the housing market over time
#
# Therefore, predictions produced by the model should be interpreted as estimates based on the available dataset rather than guaranteed market values for individual properties.
#
# ---
#
# ## 🏁 Expected Outcome
#
# At the end of this project, I expect to have developed a complete machine learning workflow that takes the housing dataset from raw data through:
#
# ```text
# Data Loading
#      ↓
# Data Understanding
#      ↓
# Data Cleaning
#      ↓
# Exploratory Data Analysis
#      ↓
# Data Visualization
#      ↓
# Feature Preparation
#      ↓
# Train/Test Split
#      ↓
# Data Preprocessing
#      ↓
# Machine Learning
#      ↓
# Prediction
#      ↓
# Evaluation
#      ↓
# Model Comparison
#      ↓
# Final Prediction
# ```
#
# The final goal is not simply to produce a predicted house value.
#
# The purpose is to demonstrate an understanding of **how a machine learning model learns from data, how data must be prepared before modelling, how different algorithms can be compared, how model performance can be evaluated, and how predictions should be interpreted responsibly**.
#
# ---
#
# # 📋 Complete Project Roadmap
#
# The project will be completed through the following stages:
#
# ### Step 1 — Import Required Libraries
#
# Import Python libraries required for data manipulation, visualization, preprocessing, machine learning, and model evaluation.
#
# ### Step 2 — Load the Dataset
#
# Load `housing.csv` into a Pandas DataFrame.
#
# ### Step 3 — Explore the Dataset
#
# Inspect the shape, columns, data types, missing values, and descriptive statistics.
#
# ### Step 4 — Define Features and Target
#
# Separate the independent variables (`X`) from the dependent variable (`y`).
#
# ### Step 5 — Identify Feature Types
#
# Separate numerical features from categorical features.
#
# ### Step 6 — Split the Dataset
#
# Divide the data into training and testing datasets.
#
# ### Step 7 — Preprocess the Data
#
# Handle missing values and encode categorical variables.
#
# ### Step 8 — Train Linear Regression
#
# Develop a baseline regression model.
#
# ### Step 9 — Train Decision Tree Regressor
#
# Develop a nonlinear tree-based regression model.
#
# ### Step 10 — Train Random Forest Regressor
#
# Develop an ensemble regression model.
#
# ### Step 11 — Generate Predictions
#
# Use each trained model to predict house values in the test dataset.
#
# ### Step 12 — Evaluate the Models
#
# Calculate MAE, RMSE, and R² for each model.
#
# ### Step 13 — Compare Model Performance
#
# Create a table comparing the performance of all models.
#
# ### Step 14 — Visualize Predictions
#
# Compare actual house values with predicted house values.
#
# ### Step 15 — Analyze Prediction Errors
#
# Examine the distribution and magnitude of model errors.
#
# ### Step 16 — Select the Best Model
#
# Identify the model with the strongest overall predictive performance.
#
# ### Step 17 — Make a New Prediction
#
# Use the selected model to predict the value of a new housing observation.
#
# ### Step 18 — Conclusion
#
# Summarize the findings, model performance, important observations, limitations, and possible future improvements.
#
# ---
#
# # 🚀 Final Project Goal
#
# The ultimate goal of this project is to demonstrate the complete process of transforming a real-world housing dataset into a **machine learning regression solution**.
#
# The project will combine:
#
# **Python + Pandas + NumPy + Matplotlib + Seaborn + Scikit-learn**
#
# to perform:
#
# **Data Analysis → Data Visualization → Data Preprocessing → Machine Learning → Prediction → Model Evaluation → Interpretation**
#
# This project will serve as a practical demonstration of the machine learning concepts learned throughout the Data Science training.
#
# ```

# %%
# ==========================================
# STEP 1: IMPORT REQUIRED LIBRARIES
# ==========================================

# Data manipulation and numerical operations
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine learning: train/test split
from sklearn.model_selection import train_test_split

# Data preprocessing
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

# Machine learning models
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# Model evaluation
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
# Load dataset

path = r"C:\Users\EHU_HEALTH_TECHNICAL\Documents\Khing_FM_Data_Science\Data_Science\assets\ts-academy_datasets\housing.csv"

df = pd.read_csv(path)

# %%
# Display first 5 rows

display(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# Let's try to understand the dataset

print("Dataset shape:", df.shape)
print("Columns:", df.columns.tolist())
print(df.dtypes)
# Out:
# Dataset shape: (20640, 10)
# Columns: ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value', 'ocean_proximity']
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity           str
# dtype: object

# %%
# Check for missing values

print("Missing Values:", df.isnull().sum())
# Out:
# Missing Values: longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
# Keep missing values for later

SimpleImputer(strategy='median')
# Out:
# SimpleImputer(strategy='median')

# %%
# Get statistical information

display(df.describe())
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# Let's visualize target variable

plt.figure(figsize=(10, 6))

sns.histplot(
    data=df,
    x='median_house_value',
    bins=50,
    kde=True,
)

plt.title('Distribution of Median House Values')
plt.xlabel('Median House Value')
plt.ylabel('Number of Districts')

plt.tight_layout()
plt.show()

# %%
# Let's look at which variables are related

plt.figure(figsize=(10, 8))

correlation = df.select_dtypes(
    include= 'number'
).corr()

sns.heatmap(
    correlation,
    annot=True,
    fmt='.2f',
    cmap='coolwarm'
)

plt.title('Correlation Matrix')

plt.tight_layout()
plt.show()

# %%
# Let's Define X and Y

# Features
x = df.drop(
    'median_house_value',
    axis=1
)

#Target
y = df['median_house_value']

print("x shape:", x.shape)
print("y shape:", y.shape)
# Out:
# x shape: (20640, 9)
# y shape: (20640,)

# %%
# Identifying numerical and categorical variables

numerical_features = [
    'longitude',
    'latitude',
    'housing_median_age',
    'total_rooms',
    'total_bedrooms',
    'population',
    'households',
    'median_income',
]

categorical_features = [
    'ocean_proximity'
]

print("Numerical features:", numerical_features)
print("\nCategorical features:", categorical_features)
# Out:
# Numerical features: ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income']
#
# Categorical features: ['ocean_proximity']

# %%
# Training and Testing
# Split data first

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.20,
    random_state=42
)

print("Training features:", x_train.shape)
print("Testing features:", x_test.shape)

print("Training target:", y_train.shape)
print("Testing target:", y_test.shape)
# Out:
# Training features: (16512, 9)
# Testing features: (4128, 9)
# Training target: (16512,)
# Testing target: (4128,)

# %%
# Data processing
# Numerical processing (Use pipeline processing)
# For missing numerical values, replace them with the median of that column.

numerical_transformer = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='median'))
    ]
)

# %%
# Create the categorical transformer

categorical_transformer = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('oneshot', OneHotEncoder(handle_unknown='ignore'))
    ]
)

# %%
# Combine the processing

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

# %%
# Now, let's create a model

linear_model = LinearRegression()

# %%
# Complete ML pipeline

linear_pipeline = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', linear_model)
    ]
)

# %%
# Train Model

linear_pipeline.fit(
    x_train,
    y_train
)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['longitude', 'latitude',
#                                                    'housing_median_age',
#                                                    'total_rooms',
#                                                    'total_bedrooms',
#                                                    'population', 'households',
#                                                    'median_income']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
# Making predictions

y_pred_linear = linear_pipeline.predict(x_test)

print(y_pred_linear[:10])
# Out:
# [ 54261.02768977 124430.91772798 255694.95828247 268208.01035998
#  262975.01360649 139811.88274639 290871.00270497 228470.45516609
#  256712.36440084 408129.43722566]

# %%
# Model Evaluation
# Mean Absolute Error (MAE)

mae_linear = mean_absolute_error(
    y_test,
    y_pred_linear
)

print(f"Linear Regression MAE: ${mae_linear:,.2f}")
# Out:
# Linear Regression MAE: $50,670.49

# %%
# Relative Mean Squared Error (RMSE)

rmse_linear = np.sqrt(
    mean_squared_error(
        y_test,
        y_pred_linear
    )
)

print(f"Linear Regression RMSE: ${rmse_linear:,.2f}")
# Out:
# Linear Regression RMSE: $70,059.19

# %%
# R-Squared (R²)

r2_linear = r2_score(
    y_test,
    y_pred_linear
)

print(f"Linear Regression R²: {r2_linear:.4f}")
# Out:
# Linear Regression R²: 0.6254

# %% [markdown]
# | Metric   |    Result | What it means                                                        |
# | -------- | -------------: | -------------------------------------------------------------------- |
# | **MAE**  | **$50,670.49** | Predictions are off by about $50.7k on average                       |
# | **RMSE** | **$70,059.19** | Larger prediction errors are penalized more heavily                  |
# | **R²**   |     **0.6254** | The model explains about **62.54%** of the variation in house values |

# %%
# Decision Tree Regression

decision_tree_model = DecisionTreeRegressor(
    random_state=42
)

decision_tree_pipeline = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', decision_tree_model)
    ]
)

# Train the model
decision_tree_pipeline.fit(
    x_train,
    y_train
)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['longitude', 'latitude',
#                                                    'housing_median_age',
#                                                    'total_rooms',
#                                                    'total_bedrooms',
#                                                    'population', 'households',
#                                                    'median_income']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
# Predictions

y_pred_tree = decision_tree_pipeline.predict(x_test)

print(y_pred_tree[:10])
# Out:
# [ 42500.  26600. 500001. 225800. 284200. 162000. 296700. 162500. 192200.
#  500001.]

# %%
# Evaluate MAE, RMSE, and R²

# MAE
mae_tree = mean_absolute_error(
    y_test,
    y_pred_tree
)

print(f"Decision Tree MAE: ${mae_tree:,.2f}")

# RMSE
rmse_tree = np.sqrt(
    mean_squared_error(
        y_test,
        y_pred_tree
    )
)

print(f"Decision Tree RMSE: ${rmse_tree:,.2f}")

# R²
r2_tree = r2_score(
    y_test,
    y_pred_tree
)

print(f"Decision Tree R²: ${r2_tree:,.2f}")
# Out:
# Decision Tree MAE: $43,631.17
# Decision Tree RMSE: $69,136.03
# Decision Tree R²: $0.64

# %%
# Random forest regression

random_forest_model = RandomForestRegressor(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)

# %%
# Random Forest pipeline
random_forest_pipeline = Pipeline(
    steps=[
        ('preprocessor', preprocessor),
        ('model', random_forest_model)
    ]
)

# %%
# Train the Random Forest

random_forest_pipeline.fit(
    x_train,
    y_train
)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['longitude', 'latitude',
#                                                    'housing_median_age',
#                                                    'total_rooms',
#                                                    'total_bedrooms',
#                                                    'population', 'households',
#                                                    'median_income']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
# Predictions

y_pred_rf = random_forest_pipeline.predict(x_test)

print("First 10 Predictions:", y_pred_rf[:10])
# Out:
# First 10 Predictions: [ 51744.    71115.   461228.37 255273.   268203.   162987.   226729.02
#  168559.   289892.05 484186.71]

# %%
# MAE
mae_rf = mean_absolute_error(
    y_test,
    y_pred_rf
)
# Lower MAE = Better

print(f"Random Forest MAE: ${mae_rf:,.2f}")

# RMSE
rmse_rf = np.sqrt(
    mean_squared_error(
        y_test,
        y_pred_rf
    )
)
# Lower RMSE = Better

print(f"Random Forest RMSE: ${rmse_rf:,.2f}")

# R²
r2_rf = r2_score(
    y_test,
    y_pred_rf
)
# Higher R² = Better

print(f"Random Forest R²: {r2_rf:,.4f}")
# Out:
# Random Forest MAE: $31,636.35
# Random Forest RMSE: $48,977.06
# Random Forest R²: 0.8169

# %%
# Lets compare all three models

model_results = pd.DataFrame({
    'Model': [
        'Linear Regression',
        'Decision Tree',
        'Random Forest'
    ],
    'MAE': [
        mae_linear,
        mae_tree,
        mae_rf
    ],
    'RMSE': [
        rmse_linear,
        rmse_tree,
        rmse_rf
    ],
    'R2': [
        r2_linear,
        r2_tree,
        r2_rf
    ]
})

display(model_results)
# Out:
#                Model           MAE          RMSE        R2
# 0  Linear Regression  50670.489236  70059.193339  0.625438
# 1      Decision Tree  43631.170543  69136.031269  0.635244
# 2      Random Forest  31636.349639  48977.063518  0.816946

# %%
# Find best model

model_results_sorted = model_results.sort_values(
    by='R2',
    ascending=False
)

display(model_results_sorted)
# Out:
#                Model           MAE          RMSE        R2
# 2      Random Forest  31636.349639  48977.063518  0.816946
# 1      Decision Tree  43631.170543  69136.031269  0.635244
# 0  Linear Regression  50670.489236  70059.193339  0.625438

# %%
# Visualize the model comparison

plt.figure(figsize=(8, 5))

sns.barplot(
    data=model_results,
    x='Model',
    y='R2'
)

plt.title('R² Score Comparison')
plt.xlabel('Model')
plt.ylabel('R² Score')
plt.ylim(0, 1)

plt.tight_layout()
plt.show()

# %%
# Actual vs Random Forrest Predictions

plt.figure(figsize=(8, 6))

sns.scatterplot(
    x=y_test,
    y=y_pred_rf,
    alpha=0.5
)

plt.xlabel('Actual House Value')
plt.ylabel('Predicted House Value')
plt.title('Random Forest: Actual vs Predicted House Values')

plt.tight_layout()
plt.show()
